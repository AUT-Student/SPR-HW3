# %% [markdown]
# <center><b>In the name of God</b></center>
#
# <b>Course</b>: Statistical Pattern Recognition
# <br>
# <b>Description:</b> HomeWork 3 | Question 3
# <br>
# <b>Developer</b>: Alireza Mazochi (400131075)

# %% [markdown]
# # Libraries

# %%
import pandas as pd
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# %% [markdown]
# # Load Dataset

# %%
data = pd.read_csv("./BOM.csv")

# %%
data
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
# 145459  2017-06-25    Uluru     14.9      NaN       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# 0            NaN           W           44.0          W  ...        71.0
# 1            NaN         WNW           44.0        NNW  ...        44.0
# 2            NaN         WSW           46.0          W  ...        38.0
# 3            NaN          NE           24.0         SE  ...        45.0
# 4            NaN           W           41.0        ENE  ...        82.0
# ...          ...         ...            ...        ...  ...         ...
# 145455       NaN           E           31.0         SE  ...        51.0
# 145456       NaN         NNW           22.0         SE  ...        56.0
# 145457       NaN           N           37.0         SE  ...        53.0
# 145458       NaN          SE           28.0        SSE  ...        51.0
# 145459       NaN         NaN            NaN        ESE  ...        62.0
#
#         Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# 0              22.0       1007.7       1007.1       8.0       NaN     16.9
# 1              25.0       1010.6       1007.8       NaN       NaN     17.2
# 2              30.0       1007.6       1008.7       NaN       2.0     21.0
# 3              16.0       1017.6       1012.8       NaN       NaN     18.1
# 4              33.0       1010.8       1006.0       7.0       8.0     17.8
# ...             ...          ...          ...       ...       ...      ...
# 145455         24.0       1024.6       1020.3       NaN       NaN     10.1
# 145456         21.0       1023.5       1019.1       NaN       NaN     10.9
# 145457         24.0       1021.0       1016.8       NaN       NaN     12.5
# 145458         24.0       1019.4       1016.5       3.0       2.0     15.1
# 145459         36.0       1020.2       1017.9       8.0       8.0     15.0
#
#         Temp3pm  RainToday  RainTomorrow
# 0          21.8         No            No
# 1          24.3         No            No
# 2          23.2         No            No
# 3          26.5         No            No
# 4          29.7         No            No
# ...         ...        ...           ...
# 145455     22.4         No            No
# 145456     24.5         No            No
# 145457     26.1         No            No
# 145458     26.0         No            No
# 145459     20.9         No           NaN
#
# [145460 rows x 23 columns]

# %% [markdown]
# # Preprocessing

# %%
data = data.dropna(axis=0, subset=["RainTomorrow"])

# %%
data["Month"] = data["Date"].apply(lambda x:int(x[5:7]))
# Out:
# <ipython-input-81-6df39a15972c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Month"] = data["Date"].apply(lambda x:int(x[5:7]))

# %%
data[['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine', 'WindGustSpeed', 'WindSpeed9am',
      'WindSpeed3pm', 'Humidity9am', 'Humidity3pm','Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
       'Temp3pm']] = data.groupby("Month").transform(lambda x:x.fillna(x.median()))
# Out:
# c:\users\alirezamazochi\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py:3188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
data[['WindGustDir', 'WindDir9am', 'WindDir3pm'
      ,'RainToday']] = data.groupby("Month").transform(lambda x:x.fillna(x.mode().iloc[0]))[['WindGustDir', 'WindDir9am', 'WindDir3pm'
      ,'RainToday']]

# %%
data.isna().any()
# Out:
# Date             False
# Location         False
# MinTemp          False
# MaxTemp          False
# Rainfall         False
# Evaporation      False
# Sunshine         False
# WindGustDir      False
# WindGustSpeed    False
# WindDir9am       False
# WindDir3pm       False
# WindSpeed9am     False
# WindSpeed3pm     False
# Humidity9am      False
# Humidity3pm      False
# Pressure9am      False
# Pressure3pm      False
# Cloud9am         False
# Cloud3pm         False
# Temp9am          False
# Temp3pm          False
# RainToday        False
# RainTomorrow     False
# Month            False
# dtype: bool

# %%
data =  data.drop(columns=["Date", "Location"])

# %%
data["RainToday"] = data["RainToday"].map({"No":0, "Yes":1})
data["RainTomorrow"] = data["RainTomorrow"].map({"No":0, "Yes":1})

direction_dict = {'E':0, 'ENE':1, 'ESE':2, 'N':3,
                  'NE':4, 'NNE':5, 'NNW': 6, 'NW':7,
                  'S':8, 'SE':9, 'SSE':10, 'SSW':11,
                  'SW':12, 'W':13, 'WNW':14,'WSW':15}

data["WindGustDir"] = data["WindGustDir"].map(direction_dict)
data["WindDir9am"] = data["WindDir9am"].map(direction_dict)
data["WindDir3pm"] = data["WindDir3pm"].map(direction_dict)

# %% [markdown]
# # Train, Test and Validation Split

# %%
data = data.sample(frac=1, random_state=0)
number_of_data = len(data)

data_train = data[0: int(number_of_data*0.6)]
data_validation = data[int(number_of_data*0.6): int(number_of_data*0.8)]
data_test = data[int(number_of_data*0.8): ]

# %% [markdown]
# # a

# %%
data_train.corr()
# Out:
#                 MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine  \
# MinTemp        1.000000  0.736445  0.101745     0.481148  0.146293
# MaxTemp        0.736445  1.000000 -0.073716     0.574821  0.430207
# Rainfall       0.101745 -0.073716  1.000000    -0.033168 -0.161280
# Evaporation    0.481148  0.574821 -0.033168     1.000000  0.392612
# Sunshine       0.146293  0.430207 -0.161280     0.392612  1.000000
# WindGustDir   -0.143288 -0.208485  0.043722    -0.072106 -0.058233
# WindGustSpeed  0.176204  0.072299  0.130025     0.191501  0.023539
# WindDir9am    -0.017437 -0.196629  0.085003    -0.062088 -0.062701
# WindDir3pm    -0.156564 -0.179289  0.049802    -0.052460 -0.036453
# WindSpeed9am   0.175776  0.016012  0.090121     0.169684  0.018506
# WindSpeed3pm   0.171910  0.049614  0.060480     0.135093  0.056834
# Humidity9am   -0.236402 -0.504268  0.218001    -0.435145 -0.386013
# Humidity3pm    0.001553 -0.502326  0.247444    -0.329813 -0.461458
# Pressure9am   -0.446419 -0.334417 -0.158659    -0.304351 -0.060100
# Pressure3pm   -0.454687 -0.420384 -0.119446    -0.320047 -0.102114
# Cloud9am       0.055230 -0.225389  0.165284    -0.162824 -0.490992
# Cloud3pm      -0.021779 -0.248255  0.142588    -0.192863 -0.531376
# Temp9am        0.899391  0.882461  0.011125     0.550117  0.309443
# Temp3pm        0.704981  0.971369 -0.074818     0.555368  0.439086
# RainToday      0.053160 -0.228056  0.496282    -0.145569 -0.233245
# RainTomorrow   0.080866 -0.159770  0.229786    -0.097857 -0.313636
# Month         -0.208177 -0.168506 -0.027170    -0.037751  0.025962
#
#                WindGustDir  WindGustSpeed  WindDir9am  WindDir3pm  \
# MinTemp          -0.143288       0.176204   -0.017437   -0.156564
# MaxTemp          -0.208485       0.072299   -0.196629   -0.179289
# Rainfall          0.043722       0.130025    0.085003    0.049802
# Evaporation      -0.072106       0.191501   -0.062088   -0.052460
# Sunshine         -0.058233       0.023539   -0.062701   -0.036453
# WindGustDir       1.000000       0.139579    0.371485    0.583371
# WindGustSpeed     0.139579       1.000000    0.059878    0.135974
# WindDir9am        0.371485       0.059878    1.000000    0.301456
# WindDir3pm        0.583371       0.135974    0.301456    1.000000
# WindSpeed9am      0.026580       0.584361    0.065024    0.048137
# WindSpeed3pm      0.099949       0.664580    0.094948    0.089184
# Humidity9am       0.056843      -0.212890    0.105709    0.024350
# Humidity3pm       0.052355      -0.028329    0.151825   -0.007264
# Pressure9am      -0.126215      -0.436144   -0.053519   -0.131697
# Pressure3pm      -0.038971      -0.395501    0.035316   -0.037959
# Cloud9am          0.063502       0.038500    0.087060    0.046870
# Cloud3pm          0.062879       0.057988    0.055584    0.051506
# Temp9am          -0.177495       0.152426   -0.104253   -0.172371
# Temp3pm          -0.219727       0.038476   -0.202424   -0.189245
# RainToday         0.127430       0.148956    0.166260    0.127684
# RainTomorrow      0.052409       0.225335    0.034256    0.032103
# Month             0.062808       0.066915    0.010240    0.045320
#
#                WindSpeed9am  ...  Humidity3pm  Pressure9am  Pressure3pm  \
# MinTemp            0.175776  ...     0.001553    -0.446419    -0.454687
# MaxTemp            0.016012  ...    -0.502326    -0.334417    -0.420384
# Rainfall           0.090121  ...     0.247444    -0.158659    -0.119446
# Evaporation        0.169684  ...    -0.329813    -0.304351    -0.320047
# Sunshine           0.018506  ...    -0.461458    -0.060100    -0.102114
# WindGustDir        0.026580  ...     0.052355    -0.126215    -0.038971
# WindGustSpeed      0.584361  ...    -0.028329    -0.436144    -0.395501
# WindDir9am         0.065024  ...     0.151825    -0.053519     0.035316
# WindDir3pm         0.048137  ...    -0.007264    -0.131697    -0.037959
# WindSpeed9am       1.000000  ...    -0.031384    -0.220745    -0.171617
# WindSpeed3pm       0.515646  ...     0.016610    -0.284156    -0.247558
# Humidity9am       -0.271241  ...     0.659875     0.143025     0.187423
# Humidity3pm       -0.031384  ...     1.000000    -0.014025     0.059218
# Pressure9am       -0.220745  ...    -0.014025     1.000000     0.960863
# Pressure3pm       -0.171617  ...     0.059218     0.960863     1.000000
# Cloud9am           0.002320  ...     0.402466    -0.096865    -0.042542
# Cloud3pm           0.018710  ...     0.419197    -0.088138    -0.040660
# Temp9am            0.130285  ...    -0.220814    -0.420659    -0.463700
# Temp3pm            0.006266  ...    -0.557023    -0.291681    -0.383660
# RainToday          0.102854  ...     0.369257    -0.178023    -0.100084
# RainTomorrow       0.092147  ...     0.437126    -0.230250    -0.211437
# Month              0.054085  ...    -0.016122     0.036914     0.027610
#
#                Cloud9am  Cloud3pm   Temp9am   Temp3pm  RainToday  \
# MinTemp        0.055230 -0.021779  0.899391  0.704981   0.053160
# MaxTemp       -0.225389 -0.248255  0.882461  0.971369  -0.228056
# Rainfall       0.165284  0.142588  0.011125 -0.074818   0.496282
# Evaporation   -0.162824 -0.192863  0.550117  0.555368  -0.145569
# Sunshine      -0.490992 -0.531376  0.309443  0.439086  -0.233245
# WindGustDir    0.063502  0.062879 -0.177495 -0.219727   0.127430
# WindGustSpeed  0.038500  0.057988  0.152426  0.038476   0.148956
# WindDir9am     0.087060  0.055584 -0.104253 -0.202424   0.166260
# WindDir3pm     0.046870  0.051506 -0.172371 -0.189245   0.127684
# WindSpeed9am   0.002320  0.018710  0.130285  0.006266   0.102854
# WindSpeed3pm   0.023011 -0.000307  0.161773  0.027282   0.081740
# Humidity9am    0.365867  0.301560 -0.474151 -0.495242   0.349176
# Humidity3pm    0.402466  0.419197 -0.220814 -0.557023   0.369257
# Pressure9am   -0.096865 -0.088138 -0.420659 -0.291681  -0.178023
# Pressure3pm   -0.042542 -0.040660 -0.463700 -0.383660  -0.100084
# Cloud9am       1.000000  0.563050 -0.115890 -0.228176   0.237295
# Cloud3pm       0.563050  1.000000 -0.137819 -0.280435   0.213675
# Temp9am       -0.115890 -0.137819  1.000000  0.850671  -0.097800
# Temp3pm       -0.228176 -0.280435  0.850671  1.000000  -0.230983
# RainToday      0.237295  0.213675 -0.097800 -0.230983   1.000000
# RainTomorrow   0.247121  0.296615 -0.026087 -0.189504   0.303200
# Month         -0.039335  0.006525 -0.140793 -0.180627   0.015349
#
#                RainTomorrow     Month
# MinTemp            0.080866 -0.208177
# MaxTemp           -0.159770 -0.168506
# Rainfall           0.229786 -0.027170
# Evaporation       -0.097857 -0.037751
# Sunshine          -0.313636  0.025962
# WindGustDir        0.052409  0.062808
# WindGustSpeed      0.225335  0.066915
# WindDir9am         0.034256  0.010240
# WindDir3pm         0.032103  0.045320
# WindSpeed9am       0.092147  0.054085
# WindSpeed3pm       0.088491  0.066726
# Humidity9am        0.251975 -0.087542
# Humidity3pm        0.437126 -0.016122
# Pressure9am       -0.230250  0.036914
# Pressure3pm       -0.211437  0.027610
# Cloud9am           0.247121 -0.039335
# Cloud3pm           0.296615  0.006525
# Temp9am           -0.026087 -0.140793
# Temp3pm           -0.189504 -0.180627
# RainToday          0.303200  0.015349
# RainTomorrow       1.000000  0.012942
# Month              0.012942  1.000000
#
# [22 rows x 22 columns]

# %%
data_train_corr = data_train.corr().abs()

print(data_train_corr.unstack().sort_values(kind="quicksort", ascending=False)[:30])
# Out:
# MinTemp        MinTemp          1.000000
# Humidity9am    Humidity9am      1.000000
# Evaporation    Evaporation      1.000000
# Sunshine       Sunshine         1.000000
# WindGustDir    WindGustDir      1.000000
# WindGustSpeed  WindGustSpeed    1.000000
# WindDir9am     WindDir9am       1.000000
# WindDir3pm     WindDir3pm       1.000000
# WindSpeed9am   WindSpeed9am     1.000000
# WindSpeed3pm   WindSpeed3pm     1.000000
# Humidity3pm    Humidity3pm      1.000000
# MaxTemp        MaxTemp          1.000000
# Pressure9am    Pressure9am      1.000000
# Pressure3pm    Pressure3pm      1.000000
# Cloud9am       Cloud9am         1.000000
# Cloud3pm       Cloud3pm         1.000000
# Temp9am        Temp9am          1.000000
# Temp3pm        Temp3pm          1.000000
# RainToday      RainToday        1.000000
# RainTomorrow   RainTomorrow     1.000000
# Rainfall       Rainfall         1.000000
# Month          Month            1.000000
# Temp3pm        MaxTemp          0.971369
# MaxTemp        Temp3pm          0.971369
# Pressure9am    Pressure3pm      0.960863
# Pressure3pm    Pressure9am      0.960863
# Temp9am        MinTemp          0.899391
# MinTemp        Temp9am          0.899391
# Temp9am        MaxTemp          0.882461
# MaxTemp        Temp9am          0.882461
# dtype: float64

# %%
redundant_features = ["MaxTemp", "Pressure9am"]
data_train = data_train.drop(columns=redundant_features)
data_validation = data_validation.drop(columns=redundant_features)
data_test = data_test.drop(columns=redundant_features)

# %% [markdown]
# # b

# %%
sfs_knn = KNeighborsClassifier(n_neighbors=11)
sfs = SequentialFeatureSelector(sfs_knn, n_features_to_select=10)
sfs.fit(data_train.drop(columns=["RainTomorrow"]), data_train["RainTomorrow"])
# Out:
# SequentialFeatureSelector(estimator=KNeighborsClassifier(n_neighbors=11),
#                           n_features_to_select=10)

# %%
import pickle

SAVE_SFS = False

if SAVE_SFS:
    pickle.dump(sfs, file = open("sfs_model.pickle", "wb"))
else:
    sfs = pickle.load(open("sfs_model.pickle", "rb"))

# %%
selected_features = data_train.drop(columns=["RainTomorrow"]).columns[sfs.get_support()]
print(selected_features)
# Out:
# Index(['Rainfall', 'Sunshine', 'WindGustSpeed', 'WindDir3pm', 'WindSpeed3pm',
#        'Humidity3pm', 'Pressure3pm', 'Temp9am', 'Temp3pm', 'Month'],
#       dtype='object')

# %% [markdown]
# # c

# %%
data_train_reduced_x = sfs.transform(data_train.drop(columns=["RainTomorrow"]))
data_train_reduced_y = data_train["RainTomorrow"]

data_test_reduced_x = sfs.transform(data_test.drop(columns=["RainTomorrow"]))
data_test_reduced_y = data_test["RainTomorrow"]

data_validation_reduced_x = sfs.transform(data_validation.drop(columns=["RainTomorrow"]))
data_validation_reduced_y = data_validation["RainTomorrow"]

# %%
k_list = []
accuracy_list = []

best_accuracy = 0
best_k = None

for k in range(1, 41, 2):

    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(data_train_reduced_x, data_train_reduced_y)

    y_real = data_validation_reduced_y
    y_predict = knn.predict(data_validation_reduced_x)

    score = accuracy_score(y_real, y_predict)

    if score>best_accuracy:
        best_accuracy = score
        best_k = k
    
    k_list.append(k)
    accuracy_list.append(score)
    
print(f"Best k = {k} with accuracy {best_accuracy}")
# Out:
# Best k = 39 with accuracy 0.8427863145680228

# %%
plt.scatter(k_list, accuracy_list)

plt.xlabel("K")
plt.ylabel("Accuracy Score")
plt.title("Accuracy Score for Validation Set Over different K")
plt.show()

# %%
knn = KNeighborsClassifier(n_neighbors=best_k)
knn.fit(data_train_reduced_x, data_train_reduced_y)

y_real = data_test_reduced_y
y_predict = knn.predict(data_test_reduced_x)

score = accuracy_score(y_real, y_predict)

print(f"Accuracy for Test Set = {score}")
# Out:
# Accuracy for Test Set = 0.8459861457857168

# %% [markdown]
# # d

# %%
new_test_data = {"Date": "2022-01-17", "Month": 1, "Location": "Rasht"
,"MinTemp": 3, "MaxTemp": 3
,"Temp9am": 3, "Temp3pm": 3
,"RainToday": 1,"Rainfall": 22.6
,"Evaporation": None, "Sunshine": None
,"WindGustDir": "NNE", "WindGustSpeed": 10.75
,"WindDir9am": "N", "WindDir3pm": "NE"
,"WindSpeed9am": 9, "WindSpeed3pm": 7
,"Humidity9am": None, "Humidity3pm": None
,"Pressure9am": 1023, "Pressure3pm": 1023
,"Cloud9am": None,"Cloud3pm": None}

# %%
data_train_month = data_train[data_train["Month"]==new_test_data["Month"]]

new_test_data["Evaporation"] = data_train_month.mean()["Evaporation"]
new_test_data["Sunshine"] = data_train_month.mean()["Sunshine"]
new_test_data["Humidity9am"] = data_train_month.mean()["Humidity9am"]
new_test_data["Humidity3pm"] = data_train_month.mean()["Humidity3pm"]
new_test_data["Cloud9am"] = data_train_month.mean()["Cloud9am"]
new_test_data["Cloud3pm"] = data_train_month.mean()["Cloud3pm"]

# %%
for feature in ["WindGustDir", "WindDir9am", "WindDir3pm"]:
    for direction in direction_dict:
        if new_test_data[feature]==direction:
            new_test_data[feature] = direction_dict[direction]
            break

# %%
x = []
for feature in selected_features:
    x.append(new_test_data[feature])

# %%
knn.predict([x])
# Out:
# array([0], dtype=int64)
